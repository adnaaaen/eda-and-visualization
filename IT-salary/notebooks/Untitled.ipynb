# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("/home/adnan/Documents/codes/data_Science/eda-and-visualization/IT-salary/data/processed/initial_cleaned_IT_survey.csv")
df.head()
# Out:
#              timestamp   age gender     city                       position  \
# 0  14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1  14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2  14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3  14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4  14/12/2018 12:50:31  39.0      M  München                    UX Designer
#
#   experience seniority_level   salary  salary_one_year_ago language  \
# 0       11.0          Senior  77000.0              76200.0  Deutsch
# 1        8.0          Senior  65000.0              55000.0  Deutsch
# 2       10.0          Senior  88000.0              73000.0  Deutsch
# 3        6.0          Senior  78000.0              55000.0  English
# 4       10.0          Senior  69000.0              60000.0  English
#
#   company_size   company_type  survey_year programming_language vacation_days  \
# ...

# %%
df['Position'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/codes/data_Science/eda-and-visualization/IT-salary/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Position'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ...

# %%
positions = ["software", "engineer", 'designer', 'developer', "developer", 'qa', 'analyist', 'senior', \
            'project', 'manager', 'team', 'lead']
sample = df['Position'].to_list()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/codes/data_Science/eda-and-visualization/IT-salary/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Position'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 3
# ...

# %%
def func(value: str, array: list[str | int]) -> str:
    if value is np.nan:
        return np.nan
    value_list = str(value).lower().split(" ")
    result_list = []
    for each in value_list:
        if each not in array:
            out = each.replace("(", " ").replace(")", " ").strip()
            result_list.append(out)
    if result_list == []:
        return np.nan
    return " ".join(result_list)

# %%
# df['new'] = df[df['Position'].notna()].apply(lambda x: func(x, positions))
df['new'] = df['Position'].apply(lambda x: func(x, positions))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/codes/data_Science/eda-and-visualization/IT-salary/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Position'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 2
# ...

# %%
df['Position'].isna().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/codes/data_Science/eda-and-visualization/IT-salary/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Position'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ...

# %%
df.head()
# Out:
#              timestamp   age gender     city                       position  \
# 0  14/12/2018 12:41:33  43.0      M  München                   QA Ingenieur
# 1  14/12/2018 12:42:09  33.0      F  München  Senior PHP Magento developer
# 2  14/12/2018 12:47:36  32.0      M  München              Software Engineer
# 3  14/12/2018 12:50:15  25.0      M  München      Senior Frontend Developer
# 4  14/12/2018 12:50:31  39.0      M  München                    UX Designer
#
#   experience seniority_level   salary  salary_one_year_ago language  \
# 0       11.0          Senior  77000.0              76200.0  Deutsch
# 1        8.0          Senior  65000.0              55000.0  Deutsch
# 2       10.0          Senior  88000.0              73000.0  Deutsch
# 3        6.0          Senior  78000.0              55000.0  English
# 4       10.0          Senior  69000.0              60000.0  English
#
#   company_size   company_type  survey_year programming_language vacation_days  \
# ...

# %%
df.isna().sum()
# Out:
# timestamp                 0
# age                     211
# gender                    9
# city                     18
# position                 17
# experience               31
# seniority_level          31
# salary                    3
# salary_one_year_ago     905
# language                 16
# company_size             27
# company_type             72
# survey_year               0
# programming_language    886
# vacation_days           873
# сontract_duration       803
# dtype: int64

# %%
wordcloud = WordCloud().generate("".join(df[df['programming_language'].notna()]['programming_language'].to_list()))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# Out:
# 0               ingenieur
# 1            php magento
# 3                frontend
# 4                      ux
# 6                 android
#               ...
# 2984                 Java
# 2985    consumer analysis
# 2986                  PHP
# 2987           JavaScript
# 2988                 yaml
# Name: programming_language, Length: 2692, dtype: object

# %%
def func(value: str, array: list[str | int]) -> str:
    if value is np.nan:
        return np.nan
    value_list = str(value).lower().split(" ")
    result_list = []
    for each in value_list:
        if each not in array:
            out = each.replace("(", " ").replace(")", " ").strip()
            result_list.append(out)
    if result_list == []:
        return np.nan
    return " ".join(result_list)
positions = ["software", "engineer", 'designer', 'developer', "developer", 'qa', 'analyist', 'senior', \
            'project', 'manager', 'team', 'lead']
df_18['programming_language'] = df_18['Position'].apply(lambda x: func(x, positions))
